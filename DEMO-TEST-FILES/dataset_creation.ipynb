# %%
import pandas as pd

# %%
#generator functions

#variable generator
def variable_generator():
    variable_lst=['i','j','k','sum','difference','var','x','product','quotient','reminder','time','count','flag','my_variable','text_count','num_of_variables','n','num','total','result','res','replace_string','d','e','f']
    for variable in variable_lst[:10]:
        yield variable

#number generator
def number_generator():
    number_lst=['zero','one','two','three','four','five','six','seven','eight','nine','one zero','two zero','two nine','three five','eight six','two four three','four eight five','one zero four','three eight six','seven nine four','eight one nine','one four three eight','six four three two','eight nine four three','two four four eight']
    for number in number_lst[:20]:
        yield number

#operator generator
def operator_generator():
    operators=['equals','not equals','less than','greater than','less than equals','greater than equals','equals equals','plus','minus','slash','slash slash','star','star star','percent','and','or','xor','plus equals','minus equals','star equals','slash equals','and equals','or equals','xor equals']
    for operator in operators:
        yield operator

#boolean operator generator
def boolean_operator_generator():
    operators=['not equals','less than','greater than','less than equals','greater than equals','equals equals']
    for operator in operators:
        yield operator

# %%
#Replace Functions

#replaces the number in words with corresponding numbers
def number_replacer(string):
    temp = string.replace(' zero ','0').replace(' one ','1').replace(' two ','2').replace(' three ','3').replace(' four ','4').replace(' five ','5').replace(' six ','6').replace(' seven ','7').replace(' eight ','8').replace(' nine ','9')
    temp = temp.replace('zero ','0').replace('one ','1').replace('two ','2').replace('three ','3').replace('four ','4').replace('five ','5').replace('six ','6').replace('seven ','7').replace('eight ','8').replace('nine ','9')
    temp = temp.replace(' zero','0').replace(' one','1').replace(' two','2').replace(' three','3').replace(' four','4').replace(' five','5').replace(' six','6').replace(' seven','7').replace(' eight','8').replace(' nine','9')
    temp = temp.replace('zero','0').replace('one','1').replace('two','2').replace('three','3').replace('four','4').replace('five','5').replace('six','6').replace('seven','7').replace('eight','8').replace('nine','9')
    return temp

#replaces the operators with corresponding operators
def operator_replacer(string):
    temp = string.replace('equals equals','==').replace('less than equals','<=').replace('greater than equals','>=').replace('not equals','!=').replace('plus equals','+=').replace('minus equals','-=').replace('star equals','*=').replace('slash equals','/=').replace('and equals','&=').replace('xor equals','|=').replace('or equals','^=').replace('less than','<').replace('greater than','>').replace('equals','=').replace('plus','+').replace('minus','-').replace('slash slash','//').replace('slash','/').replace('star star','**').replace('star','*').replace('and','&').replace('xor','^').replace('or','|').replace('percent','%').replace('true','True').replace('false','False')
    return temp

def for_loop_replacer(string):
    if 'range of' in string:
        temp = string.replace('range of','range(')
        temp = temp+"):"
    return temp
print(for_loop_replacer(number_replacer('for i in range of one eight three')))
# Out:
# for i in range(183):

# %%
intent_statements={
    "assignment_expression":[],
    "arithmetic_expression":[],
    "if_statement":["if true","if false"],
    "else_if_statement":["else if true","else if false"],
    "for_loop_declaration":[]
}

# %%
template_statements={
    "assignment_expression":["$varname equals $number","$varname equals $varname"],
    "arithmetic_expression":["$varname $operator $number","$varname $operator $varname","$number $operator $number","$operator $varname","$operator $number"],
    "if_statement":["if $varname $boolean_operator $varname","if $number $boolean_operator $number","if $varname $boolean_operator $number"],
    "else_if_statement":["else if $varname $boolean_operator $varname","else if $number $boolean_operator $number","else if $varname $boolean_operator $number"],
    "for_loop_declaration":["for $varname in range of $number","for $varname in range of $varname","for $varname in $varname"]
}

# %%
for key in template_statements:
    if key=='assignment_expression':
        for statement in template_statements[key]:
            for variable in variable_generator():
                for number in number_generator():
                    temp = statement.replace('$varname',variable)
                    temp = temp.replace('$number',number)
                    intent_statements['assignment_expression'].append(temp)
    elif key=='arithmetic_expression':
        for statement in template_statements[key]:
            for variable in variable_generator():
                for number in number_generator():
                    for operator in operator_generator():
                        temp = statement.replace('$varname',variable)
                        temp = temp.replace('$number',number)
                        temp = temp.replace('$operator',operator)
                        intent_statements['arithmetic_expression'].append(temp)
    elif key=='if_statement':
        for statement in template_statements[key]:
            for variable in variable_generator():
                for number in number_generator():
                    for operator in boolean_operator_generator():
                        temp = statement.replace('$varname',variable)
                        temp = temp.replace('$number',number)
                        temp = temp.replace('$boolean_operator',operator)
                        intent_statements['if_statement'].append(temp)
    elif key=='else_if_statement':
        for statement in template_statements[key]:
            for variable in variable_generator():
                for number in number_generator():
                    for operator in boolean_operator_generator():
                        temp = statement.replace('$varname',variable)
                        temp = temp.replace('$number',number)
                        temp = temp.replace('$boolean_operator',operator)
                        intent_statements['else_if_statement'].append(temp)
    elif key=='for_loop_declaration':
        for statement in template_statements[key]:
            for variable in variable_generator():
                for number in number_generator():
                    temp = statement.replace('$varname',variable)
                    temp = temp.replace('$number',number)
                    intent_statements['for_loop_declaration'].append(temp)
print(len(intent_statements['assignment_expression']))
print(len(intent_statements['arithmetic_expression']))
print(len(intent_statements['if_statement']))
print(len(intent_statements['else_if_statement']))
print(len(intent_statements['for_loop_declaration']))
# Out:
# 400
# 24000
# 3602
# 3602
# 600

# %%
intent_statements['for_loop_declaration']
# Out:
# ['for i in range of zero',
#  'for i in range of one',
#  'for i in range of two',
#  'for i in range of three',
#  'for i in range of four',
#  'for i in range of five',
#  'for i in range of six',
#  'for i in range of seven',
#  'for i in range of eight',
#  'for i in range of nine',
#  'for i in range of one zero',
#  'for i in range of two zero',
#  'for i in range of two nine',
#  'for i in range of three five',
#  'for i in range of eight six',
#  'for i in range of two four three',
#  'for i in range of four eight five',
#  'for i in range of one zero four',
#  'for i in range of three eight six',
#  'for i in range of seven nine four',
#  'for j in range of zero',
#  'for j in range of one',
#  'for j in range of two',
#  'for j in range of three',
#  'for j in range of four',
#  'for j in range of five',
#  'for j in range of six',
#  'for j in range of seven',
#  'for j in range of eight',
#  'for j in range of nine',
#  'for j in range of one zero',
# ...

# %%
for stmt in intent_statements['else_if_statement'][:20]:
    print(operator_replacer(number_replacer(stmt)))
# Out:
# else if True
# else if False
# else if i != i
# else if i < i
# else if i > i
# else if i <= i
# else if i >= i
# else if i == i
# else if i != i
# else if i < i
# else if i > i
# else if i <= i
# else if i >= i
# else if i == i
# else if i != i
# else if i < i
# else if i > i
# else if i <= i
# else if i >= i
# else if i == i

# %%
import playsound
import os
import random
from gtts import gTTS
import random

# %%
default_file_location = 'D:\\7th Semester\\PROJECT-WORK-PHASE-1\\CODEX-PROJECT-REPO\\AUDIO-FILES-2'

# %%
def save_audio(audio_string):
    tts = gTTS(text=audio_string,lang='en',slow=False)
    r = random.randint(1,1000000000)
    audio_file = 'audio-'+str(r)+'.mp3'
    # audio_file="hello_world.mp3"
    tts.save(os.path.join(default_file_location,audio_file))
    return audio_file

# %%
# save_audio('Hello World')
# save_audio('Hello Worldtwo ')
# Out:
# 'audio-56270982.mp3'

# %%
dataset={
    "english_statement":[],
    "intent":[],
    "programming_statement":[],
    "audio_file_name":[]
}

# %%
#Dataset Creation
def create_dataset(key):
    n=len(intent_statements[key])
    i=1
    for statement in intent_statements[key][:5000]:
        try:
            if len(statement)>180:
                continue
            dataset['audio_file_name'].append(save_audio(statement))
            temp = operator_replacer(number_replacer(statement))
            if key=='if_statement':
                temp=temp+":"
            elif key=="else_if_statement":
                temp =temp.replace('else if','elsif')
                temp = temp+":"
            elif key=='for_loop_declaration':
                temp = for_loop_replacer(number_replacer(statement))
            dataset['english_statement'].append(statement)
            dataset['intent'].append(key)
            dataset['programming_statement'].append(temp)
        
            print(f"{i}/{n} completed")
            i+=1
        except Exception as e:
            print(f"{i}/{n} completed")
            i+=1
            continue

# %%
create_dataset('assignment_expression')
# Out:
# 1/400 completed
# 2/400 completed
# 3/400 completed
# 4/400 completed
# 5/400 completed
# 6/400 completed
# 7/400 completed
# 8/400 completed
# 9/400 completed
# 10/400 completed
# 11/400 completed
# 12/400 completed
# 13/400 completed
# 14/400 completed
# 15/400 completed
# 16/400 completed
# 17/400 completed
# 18/400 completed
# 19/400 completed
# 20/400 completed
# 21/400 completed
# 22/400 completed
# 23/400 completed
# 24/400 completed
# 25/400 completed
# 26/400 completed
# 27/400 completed
# 28/400 completed
# 29/400 completed
# 30/400 completed
# 31/400 completed
# 32/400 completed
# 33/400 completed
# 34/400 completed
# 35/400 completed
# 36/400 completed
# 37/400 completed
# 38/400 completed
# 39/400 completed
# 40/400 completed
# 41/400 completed
# 42/400 completed
# 43/400 completed
# 44/400 completed
# 45/400 completed
# 46/400 completed
# 47/400 completed
# 48/400 completed
# 49/400 completed
# 50/400 completed
# 51/400 completed
# 52/400 completed
# 53/400 completed
# ...

# %%
create_dataset('arithmetic_expression')
# Out:
# 1/24000 completed
# 2/24000 completed
# 3/24000 completed
# 4/24000 completed
# 5/24000 completed
# 6/24000 completed
# 7/24000 completed
# 8/24000 completed
# 9/24000 completed
# 10/24000 completed
# 11/24000 completed
# 12/24000 completed
# 13/24000 completed
# 14/24000 completed
# 15/24000 completed
# 16/24000 completed
# 17/24000 completed
# 18/24000 completed
# 19/24000 completed
# 20/24000 completed
# 21/24000 completed
# 22/24000 completed
# 23/24000 completed
# 24/24000 completed
# 25/24000 completed
# 26/24000 completed
# 27/24000 completed
# 28/24000 completed
# 29/24000 completed
# 30/24000 completed
# 31/24000 completed
# 32/24000 completed
# 33/24000 completed
# 34/24000 completed
# 35/24000 completed
# 36/24000 completed
# 37/24000 completed
# 38/24000 completed
# 39/24000 completed
# 40/24000 completed
# 41/24000 completed
# 42/24000 completed
# 43/24000 completed
# 44/24000 completed
# 45/24000 completed
# 46/24000 completed
# 47/24000 completed
# 48/24000 completed
# ...

# %%
create_dataset('if_statement')
# Out:
# 1/3602 completed
# 2/3602 completed
# 3/3602 completed
# 4/3602 completed
# 5/3602 completed
# 6/3602 completed
# 7/3602 completed
# 8/3602 completed
# 9/3602 completed
# 10/3602 completed
# 11/3602 completed
# 12/3602 completed
# 13/3602 completed
# 14/3602 completed
# 15/3602 completed
# 16/3602 completed
# 17/3602 completed
# 18/3602 completed
# 19/3602 completed
# 20/3602 completed
# 21/3602 completed
# 22/3602 completed
# 23/3602 completed
# 24/3602 completed
# 25/3602 completed
# 26/3602 completed
# 27/3602 completed
# 28/3602 completed
# 29/3602 completed
# 30/3602 completed
# 31/3602 completed
# 32/3602 completed
# 33/3602 completed
# 34/3602 completed
# 35/3602 completed
# 36/3602 completed
# 37/3602 completed
# 38/3602 completed
# 39/3602 completed
# 40/3602 completed
# 41/3602 completed
# 42/3602 completed
# 43/3602 completed
# 44/3602 completed
# 45/3602 completed
# 46/3602 completed
# 47/3602 completed
# 48/3602 completed
# 49/3602 completed
# 50/3602 completed
# ...

# %%
create_dataset('else_if_statement')
# Out:
# 1/3602 completed
# 2/3602 completed
# 3/3602 completed
# 4/3602 completed
# 5/3602 completed
# 6/3602 completed
# 7/3602 completed
# 8/3602 completed
# 9/3602 completed
# 10/3602 completed
# 11/3602 completed
# 12/3602 completed
# 13/3602 completed
# 14/3602 completed
# 15/3602 completed
# 16/3602 completed
# 17/3602 completed
# 18/3602 completed
# 19/3602 completed
# 20/3602 completed
# 21/3602 completed
# 22/3602 completed
# 23/3602 completed
# 24/3602 completed
# 25/3602 completed
# 26/3602 completed
# 27/3602 completed
# 28/3602 completed
# 29/3602 completed
# 30/3602 completed
# 31/3602 completed
# 32/3602 completed
# 33/3602 completed
# 34/3602 completed
# 35/3602 completed
# 36/3602 completed
# 37/3602 completed
# 38/3602 completed
# 39/3602 completed
# 40/3602 completed
# 41/3602 completed
# 42/3602 completed
# 43/3602 completed
# 44/3602 completed
# 45/3602 completed
# 46/3602 completed
# 47/3602 completed
# 48/3602 completed
# 49/3602 completed
# 50/3602 completed
# ...

# %%
create_dataset('for_loop_declaration')
# Out:
# 1/600 completed
# 2/600 completed
# 3/600 completed
# 4/600 completed
# 5/600 completed
# 6/600 completed
# 7/600 completed
# 8/600 completed
# 9/600 completed
# 10/600 completed
# 11/600 completed
# 12/600 completed
# 13/600 completed
# 14/600 completed
# 15/600 completed
# 16/600 completed
# 17/600 completed
# 18/600 completed
# 19/600 completed
# 20/600 completed
# 21/600 completed
# 22/600 completed
# 23/600 completed
# 24/600 completed
# 25/600 completed
# 26/600 completed
# 27/600 completed
# 28/600 completed
# 29/600 completed
# 30/600 completed
# 31/600 completed
# 32/600 completed
# 33/600 completed
# 34/600 completed
# 35/600 completed
# 36/600 completed
# 37/600 completed
# 38/600 completed
# 39/600 completed
# 40/600 completed
# 41/600 completed
# 42/600 completed
# 43/600 completed
# 44/600 completed
# 45/600 completed
# 46/600 completed
# 47/600 completed
# 48/600 completed
# 49/600 completed
# 50/600 completed
# 51/600 completed
# 52/600 completed
# 53/600 completed
# ...

# %%
print(len(dataset['english_statement']))
print(len(dataset['intent']))
print(len(dataset['programming_statement']))
print(len(dataset['audio_file_name']))
# Out:
# 2803
# 2803
# 2803
# 2803

# %%
# print(dataset['programming_statement'][1])
# # save_audio(dataset['programming_statement'][1])
# Out:
# for i in range(1):

# %%
# df = pd.DataFrame(dataset)
# df.to_csv('arithemtic_expression_dataset.csv')

# %%
import os, glob
import pandas as pd

path = "D:\\7th Semester\\PROJECT-WORK-PHASE-1\\CODEX-PROJECT-REPO\\DEMO-TEST-FILES\\Datasets"

all_files = glob.glob(os.path.join(path, "*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged   = pd.concat(df_from_each_file, ignore_index=True)
df_merged.to_csv( "dataset.csv")

# %%
df_merged['intent'].value_counts()
# Out:
# arithmetic_expression    2803
# if_statement             1932
# else_if_statement        1275
# assignment_expression     400
# for_loop_declaration      400
# Name: intent, dtype: int64
